# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = np.random.randn(50)
y = np.random.randn(50)

plt.scatter(x, y, c=x, s = 50 + y * 30 )
plt.xlabel('x')
plt.ylabel('y')
plt.title('цвет от x, размер от y')
plt.grid()
plt.show()
